# %% [markdown]
# # Parsing Clearfield County Election results
#
# The following notebook parses the archived 2018 precinct level election results from Clearfield County from plain text into a dataframe (spreadsheet like data structure) to be used for matching.
#
# Steps:
#
# 1. Copy the plain text data from Clearfield County's [website]( https://clearfieldco.org/Election_Files/Archive/18GEPBP.HTM)
# 2. Store the plain text locally at `clearfield_raw.txt`
# 3. Use Excel's column parsing feature to create `clearfield_county.csv`
# 4. Use this script to parse the primitive csv into a csv matching Open Elections style for its statewide precinct level resutls.
# 5. Store the resulting file locally at `clearfield_county_parsed.csv`

# %%
import pandas as pd
import numpy as np
import math
import os
import re
os.getcwd()
# Out:
# '/Users/baxterdemers/pa-2018/parsing_election_results/clearfield'

# %%
df = pd.read_csv('clearfield_county.csv')
df.head()
# Out:
#               candidate  votes
# 0     RUN DATE:11/16/18    NaN
# 1     RUN TIME:10:51 AM    NaN
# 2                   NaN    NaN
# 3  0001 Brisbin Borough    NaN
# 4                   NaN  VOTES

# %% [markdown]
# ### Main parsing script

# %%
d = {
    'Straight Party':'Straight Party', 
    'United States Senator':'U.S. Senate',
    'Governor and Lieutenant Governor':'Governor',
    'REPRESENTATIVE IN CONG':'U.S. House', 
    'REPRESENTATIVE IN THE':'State House',
}
output = pd.DataFrame(columns=['county', 'precinct', 'office', 'district', 'candidate', 'party','votes', 'absentee', 'election_day'])
prev_blank = False
lst = []
first = True
for idx, row in df.iterrows():
    can = row.candidate
    if type(can) != str and math.isnan(can):
        prev_blank = True
        continue
    elif str(can)[:4].isnumeric():
        prec = can
    elif can.split()[0] in {'REGISTERED', 'PRECINCT', 'BALLOTS', 'VOTER', 'VOTE','TOTAL', 'Total', 'DISTRICT', 'Vote', 'WRITE-IN.', 'PREC', 'Run','RUN'}:
        continue
    elif prev_blank:
        if "CONGRESS" in can.upper():
            office = 'U.S. House'
            temp = re.findall(r'\d+', can.upper().split('CONGRESS')[1]) 
            district = list(map(int, temp))[0]
        elif "GENERAL ASSEMBLY" in can.upper():
            office = 'State House'
            temp = re.findall(r'\d+', can.upper().split('GENERAL ASSEMBLY')[1]) 
            district = list(map(int, temp))[0]
        else:
            district = np.nan
            office = d[can.strip()]
        prev_blank = False
    else:
        splits = can.split('(')
        can_name = splits[0].strip()
        party = splits[1].split(')')[0]
        if can_name == 'EBERT G BILL BEEMAN':
            party = 'LIB'
        res = {
            'county':'Clearfield',
            'precinct':prec,
            'office':office,
            'district':district,
            'candidate':can_name,
            'party':party,
            'votes':row.votes, 
            'absentee':np.nan, 
            'election_day':np.nan,
        }
        lst.append(res)
        if first:
            print(res)
            first = False
            
output = output.append(lst)
# Out:
# {'county': 'Clearfield', 'precinct': '0001 Brisbin Borough', 'office': 'Straight Party', 'district': nan, 'candidate': 'Democratic', 'party': 'DEM', 'votes': '12', 'absentee': nan, 'election_day': nan}

# %% [markdown]
# ### Validation

# %%
output[output.party==''].candidate.unique()
# Out:
# array([], dtype=object)

# %%
output.party.unique()
# Out:
# array(['DEM', 'REP', 'GR', 'LIB', 'REP/DEM'], dtype=object)

# %%
output.head(20)
# Out:
#         county               precinct          office  district  \
# 0   Clearfield   0001 Brisbin Borough  Straight Party       NaN
# 1   Clearfield   0001 Brisbin Borough  Straight Party       NaN
# 2   Clearfield   0001 Brisbin Borough  Straight Party       NaN
# 3   Clearfield   0001 Brisbin Borough  Straight Party       NaN
# 4   Clearfield   0001 Brisbin Borough     U.S. Senate       NaN
# 5   Clearfield   0001 Brisbin Borough     U.S. Senate       NaN
# 6   Clearfield   0001 Brisbin Borough     U.S. Senate       NaN
# 7   Clearfield   0001 Brisbin Borough     U.S. Senate       NaN
# 8   Clearfield   0001 Brisbin Borough        Governor       NaN
# 9   Clearfield   0001 Brisbin Borough        Governor       NaN
# 10  Clearfield   0001 Brisbin Borough        Governor       NaN
# 11  Clearfield   0001 Brisbin Borough        Governor       NaN
# 12  Clearfield   0001 Brisbin Borough      U.S. House      15.0
# 13  Clearfield   0001 Brisbin Borough      U.S. House      15.0
# 14  Clearfield   0001 Brisbin Borough     State House      73.0
# 15  Clearfield  0002 Burnside Borough  Straight Party       NaN
# 16  Clearfield  0002 Burnside Borough  Straight Party       NaN
# 17  Clearfield  0002 Burnside Borough  Straight Party       NaN
# 18  Clearfield  0002 Burnside Borough  Straight Party       NaN
# 19  Clearfield  0002 Burnside Borough     U.S. Senate       NaN
#
#             candidate    party votes  absentee  election_day
# 0          Democratic      DEM    12       NaN           NaN
# 1          Republican      REP    64       NaN           NaN
# 2               Green       GR     0       NaN           NaN
# 3         Libertarian      LIB     0       NaN           NaN
# 4        BOB CASEY JR      DEM    52       NaN           NaN
# 5        LOU BARLETTA      REP    88       NaN           NaN
# 6           NEAL GALE       GR     2       NaN           NaN
# 7     DALE R KERNS JR      LIB     0       NaN           NaN
# 8            TOM WOLF      DEM    41       NaN           NaN
# 9      SCOTT R WAGNER      REP    99       NaN           NaN
# 10        PAUL GLOVER       GR     0       NaN           NaN
# 11     KEN V KRAWCHUK      LIB     1       NaN           NaN
# 12        SUSAN BOSER      DEM    28       NaN           NaN
# 13  GLENN GT THOMPSON      REP   114       NaN           NaN
# 14       TOMMY SANKEY  REP/DEM   138       NaN           NaN
# 15         Democratic      DEM    13       NaN           NaN
# 16         Republican      REP    23       NaN           NaN
# 17              Green       GR     0       NaN           NaN
# 18        Libertarian      LIB     0       NaN           NaN
# 19       BOB CASEY JR      DEM    21       NaN           NaN

# %%
output.to_csv('clearfield_county_parsed.csv',index=False)
