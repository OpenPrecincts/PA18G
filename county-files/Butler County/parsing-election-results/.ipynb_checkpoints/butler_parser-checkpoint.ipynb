# %% [markdown]
# # Parsing Butler County Election results
#
# The following notebook parses the archived 2018 precinct level election results from Butler County from plain text into a dataframe (spreadsheet like data structure) to be used for matching.
#
# Steps:
#
# 1. Copy the plain text data from Butler County's [website]( https://www2.co.butler.pa.us/election/2018gen/home.htm)
# 2. Store the plain text locally at `butler_county_raw.txt`
# 3. Use Excel's column parsing feature to create `butler_county.csv`
# 4. Use this script to parse the primitive csv into a csv matching Open Elections style for its statewide precinct level resutls.
# 5. Store the resulting file locally at `butler_county_parsed.csv`

# %%
import pandas as pd
import numpy as np
import math
import os
import re
os.getcwd()
# Out:
# '/Users/baxterdemers/pa-2018/parsing_election_results/butler'

# %%
df = pd.read_csv('butler_county.csv')
df.head()
# Out:
#                                     candidate  votes election_day absentee  \
# 0                       0001 ADAMS TOWNSHIP 1    NaN          NaN      NaN
# 1                                       TOTAL    NaN          NaN      NaN
# 2  REGISTERED VOTERS - TOTAL .  .  .  .  .  .  3,957          NaN      NaN
# 3  BALLOTS CAST - TOTAL.  .  .  .  .  .  .  .  2,446        2,323      122
# 4  VOTER TURNOUT - TOTAL  .  .  .  .  .  .  .    NaN          NaN      NaN
#
#   provisional
# 0         NaN
# 1         NaN
# 2         NaN
# 3           1
# 4         NaN

# %%
output = pd.DataFrame(columns=['county', 'precinct', 'office', 'district', 'candidate', 'party','votes', 'absentee', 'election_day'])

# %%
d = {
    'STRAIGHT PARTY VOTING':'Straight Party', 
    'UNITED STATES SENATOR':'U.S. Senate',
    'GOVERNOR':'Governor',
    'REPRESENTATIVE IN CONG':'U.S. House', 
    'REPRESENTATIVE IN THE':'State House',
}

# %% [markdown]
# ### Main parsing script

# %%
prev_blank = False
lst = []
first = True
for idx, row in df.iterrows():
    can = row.candidate
    if type(can) != str and math.isnan(can):
        prev_blank = True
        continue
    elif str(can).startswith('00'):
        prec = can
    elif can.startswith('REPORT') or can.split()[0] in {'TOTAL', 'REGISTERED', 'BALLOTS', 'VOTER', 'DISTRICT', 'VOTE', 'WRITE-IN.', 'PREC', 'RUN'}:
        continue
    elif prev_blank:
        if "CONGRESS" in can:
            office = 'U.S. House'
            temp = re.findall(r'\d+', can.split('CONGRESS')[1]) 
            district = list(map(int, temp))[0]
        elif "GENERAL ASSEMBLY" in can:
            office = 'State House'
            temp = re.findall(r'\d+', can.split('GENERAL ASSEMBLY')[1]) 
            district = list(map(int, temp))[0]
        else:
            district = np.nan
            office = d[can.strip()]
        prev_blank = False
    else:
        splits = can.split('(')
        can_name = splits[0].strip()
        party = 'DEM' if can in {'LISA BOEVING-LEARNED'} else splits[1].split(')')[0]
        if can_name == 'EBERT G BILL BEEMAN':
            party = 'LIB'
        res = {
            'county':'Butler',
            'precinct':prec,
            'office':office,
            'district':district,
            'candidate':can_name,
            'party':party,
            'votes':row.votes, 
            'absentee':row.absentee, 
            'election_day':row.election_day,
        }
        lst.append(res)
        if first:
            print(res)
            first = False
            
output = output.append(lst)
# Out:
# {'county': 'Butler', 'precinct': '0001 ADAMS TOWNSHIP 1', 'office': 'Straight Party', 'district': nan, 'candidate': 'DEMOCRATIC', 'party': 'DEM', 'votes': '521', 'absentee': '29', 'election_day': '491'}

# %% [markdown]
# ### Validation

# %%
output[output.party==''].candidate.unique()
# Out:
# array([], dtype=object)

# %%
output.party.unique()
# Out:
# array(['DEM', 'REP', 'GRN', 'IND', 'LIB', 'DEM/REP'], dtype=object)

# %%
output.head(20)
# Out:
#     county               precinct          office  district  \
# 0   Butler  0001 ADAMS TOWNSHIP 1  Straight Party       NaN
# 1   Butler  0001 ADAMS TOWNSHIP 1  Straight Party       NaN
# 2   Butler  0001 ADAMS TOWNSHIP 1  Straight Party       NaN
# 3   Butler  0001 ADAMS TOWNSHIP 1  Straight Party       NaN
# 4   Butler  0001 ADAMS TOWNSHIP 1  Straight Party       NaN
# 5   Butler  0001 ADAMS TOWNSHIP 1     U.S. Senate       NaN
# 6   Butler  0001 ADAMS TOWNSHIP 1     U.S. Senate       NaN
# 7   Butler  0001 ADAMS TOWNSHIP 1     U.S. Senate       NaN
# 8   Butler  0001 ADAMS TOWNSHIP 1     U.S. Senate       NaN
# 9   Butler  0001 ADAMS TOWNSHIP 1        Governor       NaN
# 10  Butler  0001 ADAMS TOWNSHIP 1        Governor       NaN
# 11  Butler  0001 ADAMS TOWNSHIP 1        Governor       NaN
# 12  Butler  0001 ADAMS TOWNSHIP 1        Governor       NaN
# 13  Butler  0001 ADAMS TOWNSHIP 1      U.S. House      16.0
# 14  Butler  0001 ADAMS TOWNSHIP 1      U.S. House      16.0
# 15  Butler  0001 ADAMS TOWNSHIP 1      U.S. House      16.0
# 16  Butler  0001 ADAMS TOWNSHIP 1     State House      12.0
# 17  Butler  0001 ADAMS TOWNSHIP 1     State House      12.0
# 18  Butler  0002 ADAMS TOWNSHIP 2  Straight Party       NaN
# 19  Butler  0002 ADAMS TOWNSHIP 2  Straight Party       NaN
#
#               candidate party  votes absentee election_day
# 0            DEMOCRATIC   DEM    521       29          491
# 1            REPUBLICAN   REP    811       53          758
# 2                 GREEN   GRN      1        0            1
# 3           INDEPENDENT   IND      0        0            0
# 4           LIBERTARIAN   LIB      1        0            1
# 5         BOB CASEY, JR   DEM  1,047       50          996
# 6          LOU BARLETTA   REP  1,369       72        1,297
# 7             NEAL GALE   GRN      6        0            6
# 8      DALE R KERNS, JR   LIB     15        0           15
# 9              TOM WOLF   DEM  1,115       48        1,066
# 10       SCOTT R WAGNER   REP  1,295       73        1,222
# 11          PAUL GLOVER   GRN      4        0            4
# 12       KEN V KRAWCHUK   LIB     24        0           24
# 13         RON DINICOLA   DEM    947       43          903
# 14           MIKE KELLY   REP  1,473       77        1,396
# 15  EBERT G BILL BEEMAN   LIB     23        2           21
# 16   DANIEL B SMITH, JR   DEM  1,105       47        1,057
# 17       DARYL METCALFE   REP  1,319       75        1,244
# 18           DEMOCRATIC   DEM    330       37          292
# 19           REPUBLICAN   REP    759       65          693

# %%
output.to_csv('butler_county_parsed.csv',index=False)
