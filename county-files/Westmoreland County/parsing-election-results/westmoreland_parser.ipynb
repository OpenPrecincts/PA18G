# %% [markdown]
# # Parsing Westmoreland County Election results
#
# The following notebook parses the archived 2018 precinct level election results from Westmoreland County from plain text into a dataframe (spreadsheet like data structure) to be used for matching.
#
# Steps:
#
# 1. Copy the plain text data from Westmoreland County's [website]( https://www.co.westmoreland.pa.us/DocumentCenter/View/15313/2018-General-PrecinctSummary)
# 2. Store the plain text locally at `westmoreland_raw.txt`
# 3. Use Excel's column parsing feature to create `westmoreland_county.csv`
# 4. Use this script to parse the primitive csv into a csv matching Open Elections style for its statewide precinct level resutls.
# 5. Store the resulting file locally at `westmoreland_county_parsed.csv`

# %%
import pandas as pd
import numpy as np
import math
import os
import re
os.getcwd()
# Out:
# '/Users/baxterdemers/pa-2018/parsing_election_results/westmoreland'

# %%
df = pd.read_csv('westmoreland_county.csv')
df.head()
# Out:
#                                     candidate votes election_day absentee
# 0                      0100 ADAMSBURG BOROUGH   NaN          NaN      NaN
# 1                                         NaN   NaN          NaN      NaN
# 2  REGISTERED VOTERS - TOTAL .  .  .  .  .  .   112          NaN      NaN
# 3  BALLOTS CAST - TOTAL.  .  .  .  .  .  .  .    61           61        0
# 4  VOTER TURNOUT - TOTAL  .  .  .  .  .  .  .   NaN          NaN      NaN

# %% [markdown]
# ### Main parsing script

# %%
d = {
    'STRAIGHT PARTY':'Straight Party', 
    'UNITED STATES SENATOR':'U.S. Senate',
    'GOVERNOR':'Governor',
    'REPRESENTATIVE IN CONG':'U.S. House', 
    'REPRESENTATIVE IN THE':'State House',
}
output = pd.DataFrame(columns=['county', 'precinct', 'office', 'district', 'candidate', 'party','votes', 'absentee', 'election_day'])
prev_blank = False
lst = []
first = True
for idx, row in df.iterrows():
    can = row.candidate
    if type(can) != str and math.isnan(can):
        prev_blank = True
        continue
    elif str(can)[:4].isnumeric():
        prec = can
    elif can.split()[0] in {'REGISTERED', 'BALLOTS', 'VOTER','TOTAL', 'Total', 'DISTRICT', 'Vote', 'WRITE-IN.', 'PREC', 'Run'}:
        continue
    elif prev_blank:
        if "CONGRESS" in can:
            office = 'U.S. House'
            temp = re.findall(r'\d+', can.split('CONGRESS')[1]) 
            district = list(map(int, temp))[0]
        elif "GENERAL ASSEMBLY" in can:
            office = 'State House'
            temp = re.findall(r'\d+', can.split('GENERAL ASSEMBLY')[1]) 
            district = list(map(int, temp))[0]
        else:
            district = np.nan
            office = d[can.strip()]
        prev_blank = False
    else:
        splits = can.split('(')
        can_name = splits[0].strip()
        party = splits[1].split(')')[0]
        if can_name == 'EBERT G BILL BEEMAN':
            party = 'LIB'
        res = {
            'county':'Westmoreland',
            'precinct':prec,
            'office':office,
            'district':district,
            'candidate':can_name,
            'party':party,
            'votes':row.votes, 
            'absentee':row.absentee, 
            'election_day':row.election_day,
        }
        lst.append(res)
        if first:
            print(res)
            first = False
            
output = output.append(lst)
# Out:
# {'county': 'Westmoreland', 'precinct': '0100 ADAMSBURG BOROUGH', 'office': 'Straight Party', 'district': nan, 'candidate': 'Democratic', 'party': 'DEM', 'votes': '12', 'absentee': '0', 'election_day': '12'}

# %% [markdown]
# ### Validation

# %%
output[output.party==''].candidate.unique()
# Out:
# array([], dtype=object)

# %%
output.party.unique()
# Out:
# array(['DEM', 'REP', 'GRN', 'LN'], dtype=object)

# %%
output.head(20)
# Out:
#           county                   precinct          office  district  \
# 0   Westmoreland     0100 ADAMSBURG BOROUGH  Straight Party       NaN
# 1   Westmoreland     0100 ADAMSBURG BOROUGH  Straight Party       NaN
# 2   Westmoreland     0100 ADAMSBURG BOROUGH  Straight Party       NaN
# 3   Westmoreland     0100 ADAMSBURG BOROUGH  Straight Party       NaN
# 4   Westmoreland     0100 ADAMSBURG BOROUGH     U.S. Senate       NaN
# 5   Westmoreland     0100 ADAMSBURG BOROUGH     U.S. Senate       NaN
# 6   Westmoreland     0100 ADAMSBURG BOROUGH     U.S. Senate       NaN
# 7   Westmoreland     0100 ADAMSBURG BOROUGH     U.S. Senate       NaN
# 8   Westmoreland     0100 ADAMSBURG BOROUGH        Governor       NaN
# 9   Westmoreland     0100 ADAMSBURG BOROUGH        Governor       NaN
# 10  Westmoreland     0100 ADAMSBURG BOROUGH        Governor       NaN
# 11  Westmoreland     0100 ADAMSBURG BOROUGH        Governor       NaN
# 12  Westmoreland     0100 ADAMSBURG BOROUGH      U.S. House      14.0
# 13  Westmoreland     0100 ADAMSBURG BOROUGH      U.S. House      14.0
# 14  Westmoreland     0100 ADAMSBURG BOROUGH     State House      58.0
# 15  Westmoreland     0100 ADAMSBURG BOROUGH     State House      58.0
# 16  Westmoreland  0203 ALLEGHENY TWP - NO 1  Straight Party       NaN
# 17  Westmoreland  0203 ALLEGHENY TWP - NO 1  Straight Party       NaN
# 18  Westmoreland  0203 ALLEGHENY TWP - NO 1  Straight Party       NaN
# 19  Westmoreland  0203 ALLEGHENY TWP - NO 1  Straight Party       NaN
#
#             candidate party votes absentee election_day
# 0          Democratic   DEM    12        0           12
# 1          Republican   REP    20        0           20
# 2         Green Party   GRN     0        0            0
# 3         Libertarian    LN     1        0            1
# 4        Bob Casey Jr   DEM    24        0           24
# 5        Lou Barletta   REP    35        0           35
# 6           Neal Gale   GRN     0        0            0
# 7     Dale R Kerns Jr    LN     2        0            2
# 8            Tom Wolf   DEM    28        0           28
# 9      Scott R Wagner   REP    32        0           32
# 10        Paul Glover   GRN     0        0            0
# 11     Ken V Krawchuk    LN     1        0            1
# 12     Bibiana Boerio   DEM    19        0           19
# 13  Guy Reschenthaler   REP    42        0           42
# 14      Mary Popovich   DEM    21        0           21
# 15       Justin Walsh   REP    40        0           40
# 16         Democratic   DEM   279       10          269
# 17         Republican   REP   529       11          518
# 18        Green Party   GRN     0        0            0
# 19        Libertarian    LN     2        0            2

# %%
output.to_csv('westmoreland_county_parsed.csv',index=False)
