# %% [markdown]
# # Parsing Schuylkill County Election results
#
# The following notebook parses the archived 2018 precinct level election results from Schuylkill County from plain text into a dataframe (spreadsheet like data structure) to be used for matching.
#
# Steps:
#
# 1. Copy the plain text data from Schuylkill County's [website]( https://www.co.schuylkill.pa.us/info/Offices/Election/Election/Results/Info.csp?Election=64)
# 2. Store the table as a  text locally at `schuylkill.csv`
# 4. Use this script to parse the primitive csv into a csv matching Open Elections style for its statewide precinct level resutls.
# 5. Store the resulting file locally at `schuylkill_county_parsed.csv`

# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/baxterdemers/pa-2018/parsing_election_results/schuylkill'

# %%
df = pd.read_csv('schuylkill.csv')
df.head()
# Out:
#            Precinct  Votes Denny Wolff  Dan Meuser  Write-in
# 0               NaN    NaN  Democratic  Republican       NaN
# 1  Ashland 1st Pct.  405.0         198         207       0.0
# 2  Ashland 2nd Pct.  353.0         136         217       0.0
# 3       Blythe Twp.  331.0         146         184       1.0
# 4       Branch Twp.  696.0         349         347       0.0

# %%
df = df[df.index > 0]
df.head()
# Out:
#                 Precinct  Votes Denny Wolff Dan Meuser  Write-in
# 1       Ashland 1st Pct.  405.0         198        207       0.0
# 2       Ashland 2nd Pct.  353.0         136        217       0.0
# 3            Blythe Twp.  331.0         146        184       1.0
# 4            Branch Twp.  696.0         349        347       0.0
# 5  Butler Twp. Englewood  245.0          89        156       0.0

# %%
candidate_to_party = {
    'Denny Wolff':'Democratic', 
    'Dan Meuser':'Republican', 
    'Write-in':np.nan,
}

# %%
output = pd.DataFrame(columns=['county', 'precinct', 'office', 'district', 'candidate', 'party','votes', 'absentee', 'election_day'])
unpivoted = pd.melt(df, id_vars='Precinct', value_vars=['Denny Wolff', 'Dan Meuser', 'Write-in'], var_name='candidate', value_name='votes')
output = output.append(unpivoted.rename(columns={'Precinct':'precinct'}))
output.county = 'Schuylkill'
output.district = 9
output.office = 'U.S. House'
output.party = output.candidate.map(candidate_to_party)
output.head()
# Out:
#        county               precinct      office  district    candidate  \
# 0  Schuylkill       Ashland 1st Pct.  U.S. House         9  Denny Wolff
# 1  Schuylkill       Ashland 2nd Pct.  U.S. House         9  Denny Wolff
# 2  Schuylkill            Blythe Twp.  U.S. House         9  Denny Wolff
# 3  Schuylkill            Branch Twp.  U.S. House         9  Denny Wolff
# 4  Schuylkill  Butler Twp. Englewood  U.S. House         9  Denny Wolff
#
#         party votes absentee election_day
# 0  Democratic   198      NaN          NaN
# 1  Democratic   136      NaN          NaN
# 2  Democratic   146      NaN          NaN
# 3  Democratic   349      NaN          NaN
# 4  Democratic    89      NaN          NaN

# %%
output.party.unique()
# Out:
# array(['Democratic', 'Republican', nan], dtype=object)

# %%
output.head(20)
# Out:
#         county                 precinct      office  district    candidate  \
# 0   Schuylkill         Ashland 1st Pct.  U.S. House         9  Denny Wolff
# 1   Schuylkill         Ashland 2nd Pct.  U.S. House         9  Denny Wolff
# 2   Schuylkill              Blythe Twp.  U.S. House         9  Denny Wolff
# 3   Schuylkill              Branch Twp.  U.S. House         9  Denny Wolff
# 4   Schuylkill    Butler Twp. Englewood  U.S. House         9  Denny Wolff
# 5   Schuylkill  Butler Twp. Ft. Springs  U.S. House         9  Denny Wolff
# 6   Schuylkill      Butler Twp. Lavelle  U.S. House         9  Denny Wolff
# 7   Schuylkill    Butler Twp. Northeast  U.S. House         9  Denny Wolff
# 8   Schuylkill          Cass Twp. North  U.S. House         9  Denny Wolff
# 9   Schuylkill          Cass Twp. South  U.S. House         9  Denny Wolff
# 10  Schuylkill              Delano Twp.  U.S. House         9  Denny Wolff
# 11  Schuylkill      East Norwegian Twp.  U.S. House         9  Denny Wolff
# 12  Schuylkill         Frackville North  U.S. House         9  Denny Wolff
# 13  Schuylkill        Frackville Middle  U.S. House         9  Denny Wolff
# 14  Schuylkill         Frackville South  U.S. House         9  Denny Wolff
# 15  Schuylkill                Gilberton  U.S. House         9  Denny Wolff
# 16  Schuylkill              Girardville  U.S. House         9  Denny Wolff
# 17  Schuylkill                   Gordon  U.S. House         9  Denny Wolff
# 18  Schuylkill      Mahanoy City Pct. 1  U.S. House         9  Denny Wolff
# 19  Schuylkill      Mahanoy City Pct. 2  U.S. House         9  Denny Wolff
#
#          party votes absentee election_day
# 0   Democratic   198      NaN          NaN
# 1   Democratic   136      NaN          NaN
# 2   Democratic   146      NaN          NaN
# 3   Democratic   349      NaN          NaN
# 4   Democratic    89      NaN          NaN
# 5   Democratic   251      NaN          NaN
# 6   Democratic   198      NaN          NaN
# 7   Democratic    53      NaN          NaN
# 8   Democratic    73      NaN          NaN
# 9   Democratic   231      NaN          NaN
# 10  Democratic    60      NaN          NaN
# 11  Democratic   193      NaN          NaN
# 12  Democratic   161      NaN          NaN
# 13  Democratic   126      NaN          NaN
# 14  Democratic   260      NaN          NaN
# 15  Democratic   104      NaN          NaN
# 16  Democratic   187      NaN          NaN
# 17  Democratic   131      NaN          NaN
# 18  Democratic    60      NaN          NaN
# 19  Democratic   147      NaN          NaN

# %%
output.to_csv('schuylkill_county_parsed.csv',index=False)
